# %% [markdown]
# # Business Problem and Background
#
#     I represent a national donut shop, Galaxy Donuts, and we are expanding into the state of Minnesota. Our focus is on finding locations in the city of Minneapolis that will maximize profitability for the company. The biggest problem identified by our new CEO is our donut competition has been established for some time in the Minneapolis area. However, based on our proprietary Donut Density Ratio (DDR) we know there is room for one location for our brand.
#
#     We will need to analyze the 83 neighborhoods of Minneapolis proper, and make the decision based on optimal distance from location of competitor donut shops in and around Minneapolis. We also want to place our store in a neighborhood with a low crime rate. Finally, we want to place the location of our stores in higher density areas that will ensure plenty of traffic, as well as other activities for our customers to do after they have their minds blown by our donuts.

# %% [markdown]
# # The Data
#
#     I will be using the Foursquare API to identify all donut shops in and around the city of Minneapolis. These will be indicated with red dots on the map. Next, I will determine which neighborhoods are the optimal/maximal distance from the other donut shops.
#
#     Once I have that list of neighborhoods, I will analyze those specific neighborhoods, dividing out all residential and industrial space, leaving only commercial space. I will also map the crime rate by neighborhood. To do this, I will utilize city of Minneapolis open source data to help with this determination. Then I will use the Foursquare API to find businesses that might complement a donut shop (list still being determined, but will be included in the final report), and attempt to place the neighborhood in an area where the mean customer scores are highest, indicating a more satisfying experience/location.
#
#     The final work product will be a map of Minneapolis, linked to the Foursquare API denoting all competitors, and I will use all the data discussed above to place the coveted blue dot where Galaxy Donuts will open its newest location(s). All the findings will be returned in a formatted report with visuals, and I will also write the computer program used for analysis in a Jupyter Notebook and share it on my Github page with my colleagues.

# %%
# I first import all the libraries I need for my initial analysis
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#I bring in a csv titles 'Neighborhood Crime Stats' and convert it to a dataframe
mpls_nbrhd = pd.read_csv('NEIGHBORHOOD_CRIME_STATS.csv', delimiter = ',')

# %%
#I use the groupby method to get sum total of crimes by each neighborhood
mpls_nbrhd = mpls_nbrhd.groupby('neighborhood')['number'].sum()

# %%
#This displays the summed dataframe of Minneapolis neighborhoods
mpls_nbrhd.to_frame()
# Out:
#                number
# neighborhood
# Armatage          193
# Audubon Park      362
# Bancroft          212
# Beltrami          121
# Bottineau         161
# ...               ...
# West Calhoun      185
# Whittier         1894
# Willard - Hay     848
# Windom            318
# Windom Park       310
#
# [87 rows x 1 columns]

# %%
#I reset the index to make the dataframe easier to manipulate and convert it to pf1
mpls_nbrhd1 = mpls_nbrhd.reset_index()
mpls_nbrhd1
# Out:
#      neighborhood  number
# 0        Armatage     193
# 1    Audubon Park     362
# 2        Bancroft     212
# 3        Beltrami     121
# 4       Bottineau     161
# ..            ...     ...
# 82   West Calhoun     185
# 83       Whittier    1894
# 84  Willard - Hay     848
# 85         Windom     318
# 86    Windom Park     310
#
# [87 rows x 2 columns]

# %%
# !conda install -c conda-forge folium=0.7.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed and imported!

# %%
from folium import plugins
# !wget --quiet https://opendata.arcgis.com/datasets/055ca54e5fcc47329f081c9ef51d038e_0.geojson -O 055ca54e5fcc47329f081c9ef51d038e_0.geojson

print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
# Minneapolis latitude and longitude values
latitude = 44.986656
longitude = -93.258133
mpls_neighborhood_geo = 'https://opendata.arcgis.com/datasets/055ca54e5fcc47329f081c9ef51d038e_0.geojson'

# Create map
mpls_map = folium.Map(
       location=[latitude,longitude],
       zoom_start=11.35)

mpls_map.choropleth(
    geo_data=mpls_neighborhood_geo,
    data=mpls_nbrhd1,
    columns=['neighborhood','number'],
    key_on='feature.properties.BDNAME',
    threshold_scale=[0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500],
    fill_color='YlOrRd',
    fill_opacity='0.7',
    line_opacity='0.2',
    legend_name='Crime Rate in Minneapolis',
    reset=True,
)
# display the map
mpls_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# %%
CLIENT_ID = 'G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX' # your Foursquare ID
CLIENT_SECRET = 'WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX
# CLIENT_SECRET:WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC

# %%
url = 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d148941735&intent=browse&radius=30000&client_id={}&client_secret={}&ll={},{}&v={}&query='.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d148941735&intent=browse&radius=30000&client_id=G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX&client_secret=WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC&ll=44.986656,-93.258133&v=20180604&query='

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5db756116b9b490028966c77'},
#  'response': {'venues': [{'id': '584c04838ee56059df135672',
#     'name': "Dunkin'",
#     'location': {'address': 'MSP Airport, Terminal 1',
#      'crossStreet': 'Main Concourse',
#      'lat': 44.88374364677225,
#      'lng': -93.21137493853037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.88374364677225,
#        'lng': -93.21137493853037}],
#      'distance': 12034,
#      'postalCode': '55111',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['MSP Airport, Terminal 1 (Main Concourse)',
#       'Saint Paul, MN 55111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '580fa20238facc4e6ffd1569',
#     'name': 'Angel Food Bakery & Donut Bar',
#     'location': {'address': 'Concourse E',
#      'lat': 44.8850400628044,
#      'lng': -93.21256634765209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.8850400628044,
#        'lng': -93.21256634765209}],
#      'distance': 11868,
#      'postalCode': '55111',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Concourse E',
#       'Saint Paul, MN 55111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '58517cc7739d855b44e53255',
#     'name': "Dunkin'",
#     'location': {'address': '2425 Rice St',
#      'lat': 45.01396688648932,
#      'lng': -93.1067315053491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.01396688648932,
#        'lng': -93.1067315053491}],
#      'distance': 12299,
#      'postalCode': '55113',
#      'cc': 'US',
#      'city': 'Roseville',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2425 Rice St',
#       'Roseville, MN 55113',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '51254ee3e4b0597635a30975',
#     'name': 'Glam Doll Donuts',
#     'location': {'address': '2605 Nicollet Ave',
#      'crossStreet': 'at E 26th St.',
#      'lat': 44.955156072462565,
#      'lng': -93.27781590260867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.955156072462565,
#        'lng': -93.27781590260867}],
#      'distance': 3833,
#      'postalCode': '55408',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2605 Nicollet Ave (at E 26th St.)',
#       'Minneapolis, MN 55408',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '4b5864b8f964a520c35528e3',
#     'name': 'Donut Connection',
#     'location': {'address': '1037 1st Ave E',
#      'lat': 44.80054540165129,
#      'lng': -93.5131151359874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.80054540165129,
#        'lng': -93.5131151359874}],
#      'distance': 28871,
#      'postalCode': '55379',
#      'cc': 'US',
#      'city': 'Shakopee',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1037 1st Ave E',
#       'Shakopee, MN 55379',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5beee5d5625a66002c783fba',
#     'name': "Dunkin'",
#     'location': {'lat': 44.88410763898639,
#      'lng': -93.30836257250284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.88410763898639,
#        'lng': -93.30836257250284}],
#      'distance': 12082,
#      'postalCode': '55423',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55423', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '451f6c35f964a5209e3a1fe3',
#     'name': 'Mel-O-Glaze Bakery',
#     'location': {'address': '4800 28th Ave S',
#      'crossStreet': 'at E Minnehaha Pkwy',
#      'lat': 44.91586386149392,
#      'lng': -93.23230649696275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.91586386149392,
#        'lng': -93.23230649696275}],
#      'distance': 8138,
#      'postalCode': '55417',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4800 28th Ave S (at E Minnehaha Pkwy)',
#       'Minneapolis, MN 55417',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5b142c22c58ed7002c9219a1',
#     'name': "Dunkin'",
#     'location': {'address': '9595 Zachary Ln N',
#      'lat': 45.128771760267725,
#      'lng': -93.42302326667033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.128771760267725,
#        'lng': -93.42302326667033}],
#      'distance': 20454,
#      'postalCode': '55369',
#      'cc': 'US',
#      'city': 'Maple Grove',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['9595 Zachary Ln N',
#       'Maple Grove, MN 55369',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5d9e2d3d3155f3000bd6a06c',
#     'name': "Dunkin'",
#     'location': {'address': '143 Snelling Ave N',
#      'lat': 44.9456218,
#      'lng': -93.16731779999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.9456218,
#        'lng': -93.16731779999999}],
#      'distance': 8486,
#      'postalCode': '55104',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['143 Snelling Ave N',
#       'Saint Paul, MN 55104',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5cb20be9a35f46002557ea67',
#     'name': "Dunkin'",
#     'location': {'address': '1420 Yankee Doodle Rd',
#      'crossStreet': 'at Pilot Knob Rd',
#      'lat': 44.8331594,
#      'lng': -93.1687155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.8331594,
#        'lng': -93.1687155}],
#      'distance': 18484,
#      'postalCode': '55121',
#      'cc': 'US',
#      'city': 'Eagan',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1420 Yankee Doodle Rd (at Pilot Knob Rd)',
#       'Eagan, MN 55121',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '59144c1a5d891b0a80017201',
#     'name': 'Cardigan Donuts',
#     'location': {'address': '40 S 7th St #207',
#      'lat': 44.97772595833002,
#      'lng': -93.27324894412774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97772595833002,
#        'lng': -93.27324894412774}],
#      'distance': 1550,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['40 S 7th St #207',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '589115',
#      'url': 'https://www.grubhub.com/restaurant/cardigan-donuts-40-s-7th-st-ste-207-minneapolis/589115?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=589115',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5855d840ce593d5304f96945',
#     'name': 'Glam Doll Donuts',
#     'location': {'address': '519 Central Ave NE',
#      'lat': 44.98958329159745,
#      'lng': -93.25266389631834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98958329159745,
#        'lng': -93.25266389631834}],
#      'distance': 539,
#      'postalCode': '55413',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['519 Central Ave NE',
#       'Minneapolis, MN 55413',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5aa4240b4a1cc021996bbdb3',
#     'name': 'The Thirsty Whale',
#     'location': {'address': '4149 Fremont Ave N',
#      'lat': 45.03128143363127,
#      'lng': -93.29587187241299,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.03128143363127,
#        'lng': -93.29587187241299}],
#      'distance': 5787,
#      'postalCode': '55412',
#      'cc': 'US',
#      'neighborhood': 'Webber - Camden',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4149 Fremont Ave N',
#       'Minneapolis, MN 55412',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5a49d561e55d8b05322b7445',
#     'name': "Sleepy V's",
#     'location': {'address': '1226 2nd St NE',
#      'crossStreet': '13th',
#      'lat': 45.00075584468196,
#      'lng': -93.26630711664653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.00075584468196,
#        'lng': -93.26630711664653}],
#      'distance': 1696,
#      'postalCode': '55413',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1226 2nd St NE (13th)',
#       'Minneapolis, MN 55413',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '53872b4c498e75f52c1389e9',
#     'name': "Bogart's Doughnut Co.",
#     'location': {'address': '904 W 36th St',
#      'lat': 44.937735526956516,
#      'lng': -93.29105600533794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.937735526956516,
#        'lng': -93.29105600533794}],
#      'distance': 6031,
#      'postalCode': '55408',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['904 W 36th St',
#       'Minneapolis, MN 55408',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90123245'},
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '4c629ec6edd320a1a046ad29',
#     'name': 'Puffy Cream Donuts',
#     'location': {'address': '3390 Coachman Rd',
#      'crossStreet': 'Yankee Doodle Rd',
#      'lat': 44.83384107852124,
#      'lng': -93.17957700674667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.83384107852124,
#        'lng': -93.17957700674667}],
#      'distance': 18103,
#      'postalCode': '55121',
#      'cc': 'US',
#      'city': 'Eagan',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['3390 Coachman Rd (Yankee Doodle Rd)',
#       'Eagan, MN 55121',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '4bc4d71fabf495213ea5c593',
#     'name': 'YoYo Donuts & Coffee Bar',
#     'location': {'address': '5757 Sanibel Dr',
#      'crossStreet': 'at Shady Oak Road',
#      'lat': 44.900312699515695,
#      'lng': -93.42233441664136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.900312699515695,
#        'lng': -93.42233441664136}],
#      'distance': 16117,
#      'postalCode': '55343',
#      'cc': 'US',
#      'city': 'Hopkins',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['5757 Sanibel Dr (at Shady Oak Road)',
#       'Hopkins, MN 55343',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '54181465'},
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '58bc67512bc5e25a80ce4ec8',
#     'name': "Dunkin'",
#     'location': {'address': '13650 Hanson Blvd NW Ste 114',
#      'lat': 45.218714888550714,
#      'lng': -93.30708173843391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.218714888550714,
#        'lng': -93.30708173843391}],
#      'distance': 26117,
#      'postalCode': '55304',
#      'cc': 'US',
#      'city': 'Andover',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['13650 Hanson Blvd NW Ste 114',
#       'Andover, MN 55304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5cbb22a5ad910e002c3cb5cf',
#     'name': "Dunkin'",
#     'location': {'address': '1275 County Road D E Ste 106B',
#      'lat': 45.0322857,
#      'lng': -93.0461134,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.0322857,
#        'lng': -93.0461134}],
#      'distance': 17442,
#      'postalCode': '55109',
#      'cc': 'US',
#      'city': 'Maplewood',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1275 County Road D E Ste 106B',
#       'Maplewood, MN 55109',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16d941735',
#       'name': 'Café',
#       'pluralName': 'Cafés',
#       'shortName': 'Café',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '583ba09f14250b703bae9aa5',
#     'name': "Dunkin'",
#     'location': {'address': '7820 42nd Ave N',
#      'lat': 45.03319412589679,
#      'lng': -93.37891064123318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.03319412589679,
#        'lng': -93.37891064123318}],
#      'distance': 10825,
#      'postalCode': '55427',
#      'cc': 'US',
#      'neighborhood': 'Robbinsdale - Crystal - New Hope',
#      'city': 'New Hope',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['7820 42nd Ave N',
#       'New Hope, MN 55427',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '59b7cebd6f706a0386a204e3',
#     'name': "Dunkin'",
#     'location': {'lat': 44.90933094406156,
#      'lng': -93.08006309858256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.90933094406156,
#        'lng': -93.08006309858256}],
#      'distance': 16459,
#      'postalCode': '55118',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Saint Paul, MN 55118', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5ba55c073092be002c61098e',
#     'name': 'Bogart’s Doughnut Co',
#     'location': {'lat': 44.928523,
#      'lng': -93.124586,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.928523,
#        'lng': -93.124586}],
#      'distance': 12350,
#      'postalCode': '55102',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Saint Paul, MN 55102', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5c0bd903270ee7002cb99b6c',
#     'name': 'Duck Donuts',
#     'location': {'address': '7455 Currell Blvd',
#      'crossStreet': 'Bielenberg Dr',
#      'lat': 44.92499,
#      'lng': -92.95511,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.92499,
#        'lng': -92.95511}],
#      'distance': 24838,
#      'postalCode': '55125',
#      'cc': 'US',
#      'city': 'Woodbury',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['7455 Currell Blvd (Bielenberg Dr)',
#       'Woodbury, MN 55125',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '56c88ed8498e6709eee088c6',
#     'name': "Mucci's",
#     'location': {'address': '786 Randolph Ave',
#      'lat': 44.92677654048905,
#      'lng': -93.13330789970918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.92677654048905,
#        'lng': -93.13330789970918}],
#      'distance': 11879,
#      'postalCode': '55102',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['786 Randolph Ave',
#       'Saint Paul, MN 55102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5c8ee7241f8ed6002cc3d397',
#     'name': "Dunkin' Donuts",
#     'location': {'address': '8300 University Ave NE',
#      'lat': 45.119137,
#      'lng': -93.264728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.119137,
#        'lng': -93.264728}],
#      'distance': 14756,
#      'postalCode': '55432',
#      'cc': 'US',
#      'city': 'Fridley',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['8300 University Ave NE',
#       'Fridley, MN 55432',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False},
#    {'id': '5a4137d1ea1e441230558076',
#     'name': "Dunkin'",
#     'location': {'address': '1700 American Blvd E',
#      'lat': 44.86081498790423,
#      'lng': -93.25068188095094,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.86081498790423,
#        'lng': -93.25068188095094}],
#      'distance': 14020,
#      'postalCode': '55425',
#      'cc': 'US',
#      'city': 'Bloomington',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1700 American Blvd E',
#       'Bloomington, MN 55425',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1572296231',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                           name  \
# 0  584c04838ee56059df135672                        Dunkin'
# 1  580fa20238facc4e6ffd1569  Angel Food Bakery & Donut Bar
# 2  58517cc7739d855b44e53255                        Dunkin'
# 3  51254ee3e4b0597635a30975               Glam Doll Donuts
# 4  4b5864b8f964a520c35528e3               Donut Connection
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1572296231    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1572296231    False
# 2  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1572296231    False
# 3  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1572296231    False
# 4  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1572296231    False
#
#           location.address location.crossStreet  location.lat  location.lng  \
# 0  MSP Airport, Terminal 1       Main Concourse     44.883744    -93.211375
# 1              Concourse E                  NaN     44.885040    -93.212566
# 2             2425 Rice St                  NaN     45.013967    -93.106732
# 3        2605 Nicollet Ave        at E 26th St.     44.955156    -93.277816
# 4           1037 1st Ave E                  NaN     44.800545    -93.513115
#
#                              location.labeledLatLngs  ...  location.country  \
# 0  [{'label': 'display', 'lat': 44.88374364677225...  ...     United States
# 1  [{'label': 'display', 'lat': 44.8850400628044,...  ...     United States
# 2  [{'label': 'display', 'lat': 45.01396688648932...  ...     United States
# 3  [{'label': 'display', 'lat': 44.95515607246256...  ...     United States
# 4  [{'label': 'display', 'lat': 44.80054540165129...  ...     United States
#
#                            location.formattedAddress delivery.id delivery.url  \
# 0  [MSP Airport, Terminal 1 (Main Concourse), Sai...         NaN          NaN
# 1  [Concourse E, Saint Paul, MN 55111, United Sta...         NaN          NaN
# 2  [2425 Rice St, Roseville, MN 55113, United Sta...         NaN          NaN
# 3  [2605 Nicollet Ave (at E 26th St.), Minneapoli...         NaN          NaN
# 4  [1037 1st Ave E, Shakopee, MN 55379, United St...         NaN          NaN
#
#   delivery.provider.name delivery.provider.icon.prefix  \
# 0                    NaN                           NaN
# 1                    NaN                           NaN
# 2                    NaN                           NaN
# 3                    NaN                           NaN
# 4                    NaN                           NaN
#
#   delivery.provider.icon.sizes delivery.provider.icon.name  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                         NaN
#
#   location.neighborhood venuePage.id
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
#
# [5 rows x 25 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                              name          categories  \
# 0                         Dunkin'          Donut Shop
# 1   Angel Food Bakery & Donut Bar              Bakery
# 2                         Dunkin'          Donut Shop
# 3                Glam Doll Donuts          Donut Shop
# 4                Donut Connection          Donut Shop
# 5                         Dunkin'          Donut Shop
# 6              Mel-O-Glaze Bakery              Bakery
# 7                         Dunkin'          Donut Shop
# 8                         Dunkin'                Café
# 9                         Dunkin'          Donut Shop
# 10                Cardigan Donuts          Donut Shop
# 11               Glam Doll Donuts          Donut Shop
# 12              The Thirsty Whale              Bakery
# 13                     Sleepy V's          Donut Shop
# 14          Bogart's Doughnut Co.          Donut Shop
# 15             Puffy Cream Donuts          Donut Shop
# 16       YoYo Donuts & Coffee Bar          Donut Shop
# 17                        Dunkin'          Donut Shop
# 18                        Dunkin'                Café
# 19                        Dunkin'          Donut Shop
# 20                        Dunkin'          Donut Shop
# 21           Bogart’s Doughnut Co          Donut Shop
# 22                    Duck Donuts          Donut Shop
# 23                        Mucci's  Italian Restaurant
# 24                 Dunkin' Donuts          Donut Shop
# 25                        Dunkin'          Donut Shop
#
#                           address          crossStreet        lat        lng  \
# 0         MSP Airport, Terminal 1       Main Concourse  44.883744 -93.211375
# 1                     Concourse E                  NaN  44.885040 -93.212566
# 2                    2425 Rice St                  NaN  45.013967 -93.106732
# 3               2605 Nicollet Ave        at E 26th St.  44.955156 -93.277816
# 4                  1037 1st Ave E                  NaN  44.800545 -93.513115
# 5                             NaN                  NaN  44.884108 -93.308363
# 6                 4800 28th Ave S  at E Minnehaha Pkwy  44.915864 -93.232306
# 7               9595 Zachary Ln N                  NaN  45.128772 -93.423023
# 8              143 Snelling Ave N                  NaN  44.945622 -93.167318
# 9           1420 Yankee Doodle Rd     at Pilot Knob Rd  44.833159 -93.168716
# 10               40 S 7th St #207                  NaN  44.977726 -93.273249
# 11             519 Central Ave NE                  NaN  44.989583 -93.252664
# 12             4149 Fremont Ave N                  NaN  45.031281 -93.295872
# 13                 1226 2nd St NE                 13th  45.000756 -93.266307
# 14                  904 W 36th St                  NaN  44.937736 -93.291056
# 15               3390 Coachman Rd     Yankee Doodle Rd  44.833841 -93.179577
# 16                5757 Sanibel Dr    at Shady Oak Road  44.900313 -93.422334
# 17   13650 Hanson Blvd NW Ste 114                  NaN  45.218715 -93.307082
# 18  1275 County Road D E Ste 106B                  NaN  45.032286 -93.046113
# 19                7820 42nd Ave N                  NaN  45.033194 -93.378911
# 20                            NaN                  NaN  44.909331 -93.080063
# 21                            NaN                  NaN  44.928523 -93.124586
# 22              7455 Currell Blvd        Bielenberg Dr  44.924990 -92.955110
# 23               786 Randolph Ave                  NaN  44.926777 -93.133308
# 24         8300 University Ave NE                  NaN  45.119137 -93.264728
# 25           1700 American Blvd E                  NaN  44.860815 -93.250682
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 44.88374364677225...     12034      55111
# 1   [{'label': 'display', 'lat': 44.8850400628044,...     11868      55111
# 2   [{'label': 'display', 'lat': 45.01396688648932...     12299      55113
# 3   [{'label': 'display', 'lat': 44.95515607246256...      3833      55408
# 4   [{'label': 'display', 'lat': 44.80054540165129...     28871      55379
# 5   [{'label': 'display', 'lat': 44.88410763898639...     12082      55423
# 6   [{'label': 'display', 'lat': 44.91586386149392...      8138      55417
# 7   [{'label': 'display', 'lat': 45.12877176026772...     20454      55369
# 8   [{'label': 'display', 'lat': 44.9456218, 'lng'...      8486      55104
# 9   [{'label': 'display', 'lat': 44.8331594, 'lng'...     18484      55121
# 10  [{'label': 'display', 'lat': 44.97772595833002...      1550      55454
# 11  [{'label': 'display', 'lat': 44.98958329159745...       539      55413
# 12  [{'label': 'display', 'lat': 45.03128143363127...      5787      55412
# 13  [{'label': 'display', 'lat': 45.00075584468196...      1696      55413
# 14  [{'label': 'display', 'lat': 44.93773552695651...      6031      55408
# 15  [{'label': 'display', 'lat': 44.83384107852124...     18103      55121
# 16  [{'label': 'display', 'lat': 44.90031269951569...     16117      55343
# 17  [{'label': 'display', 'lat': 45.21871488855071...     26117      55304
# 18  [{'label': 'display', 'lat': 45.0322857, 'lng'...     17442      55109
# 19  [{'label': 'display', 'lat': 45.03319412589679...     10825      55427
# 20  [{'label': 'display', 'lat': 44.90933094406156...     16459      55118
# 21  [{'label': 'display', 'lat': 44.928523, 'lng':...     12350      55102
# 22  [{'label': 'display', 'lat': 44.92499, 'lng': ...     24838      55125
# 23  [{'label': 'display', 'lat': 44.92677654048905...     11879      55102
# 24  [{'label': 'display', 'lat': 45.119137, 'lng':...     14756      55432
# 25  [{'label': 'display', 'lat': 44.86081498790423...     14020      55425
#
#     cc         city state        country  \
# 0   US   Saint Paul    MN  United States
# 1   US   Saint Paul    MN  United States
# 2   US    Roseville    MN  United States
# 3   US  Minneapolis    MN  United States
# 4   US     Shakopee    MN  United States
# 5   US  Minneapolis    MN  United States
# 6   US  Minneapolis    MN  United States
# 7   US  Maple Grove    MN  United States
# 8   US   Saint Paul    MN  United States
# 9   US        Eagan    MN  United States
# 10  US  Minneapolis    MN  United States
# 11  US  Minneapolis    MN  United States
# 12  US  Minneapolis    MN  United States
# 13  US  Minneapolis    MN  United States
# 14  US  Minneapolis    MN  United States
# 15  US        Eagan    MN  United States
# 16  US      Hopkins    MN  United States
# 17  US      Andover    MN  United States
# 18  US    Maplewood    MN  United States
# 19  US     New Hope    MN  United States
# 20  US   Saint Paul    MN  United States
# 21  US   Saint Paul    MN  United States
# 22  US     Woodbury    MN  United States
# 23  US   Saint Paul    MN  United States
# 24  US      Fridley    MN  United States
# 25  US  Bloomington    MN  United States
#
#                                      formattedAddress  \
# 0   [MSP Airport, Terminal 1 (Main Concourse), Sai...
# 1   [Concourse E, Saint Paul, MN 55111, United Sta...
# 2   [2425 Rice St, Roseville, MN 55113, United Sta...
# 3   [2605 Nicollet Ave (at E 26th St.), Minneapoli...
# 4   [1037 1st Ave E, Shakopee, MN 55379, United St...
# 5              [Minneapolis, MN 55423, United States]
# 6   [4800 28th Ave S (at E Minnehaha Pkwy), Minnea...
# 7   [9595 Zachary Ln N, Maple Grove, MN 55369, Uni...
# 8   [143 Snelling Ave N, Saint Paul, MN 55104, Uni...
# 9   [1420 Yankee Doodle Rd (at Pilot Knob Rd), Eag...
# 10  [40 S 7th St #207, Minneapolis, MN 55454, Unit...
# 11  [519 Central Ave NE, Minneapolis, MN 55413, Un...
# 12  [4149 Fremont Ave N, Minneapolis, MN 55412, Un...
# 13  [1226 2nd St NE (13th), Minneapolis, MN 55413,...
# 14  [904 W 36th St, Minneapolis, MN 55408, United ...
# 15  [3390 Coachman Rd (Yankee Doodle Rd), Eagan, M...
# 16  [5757 Sanibel Dr (at Shady Oak Road), Hopkins,...
# 17  [13650 Hanson Blvd NW Ste 114, Andover, MN 553...
# 18  [1275 County Road D E Ste 106B, Maplewood, MN ...
# 19  [7820 42nd Ave N, New Hope, MN 55427, United S...
# 20              [Saint Paul, MN 55118, United States]
# 21              [Saint Paul, MN 55102, United States]
# 22  [7455 Currell Blvd (Bielenberg Dr), Woodbury, ...
# 23  [786 Randolph Ave, Saint Paul, MN 55102, Unite...
# 24  [8300 University Ave NE, Fridley, MN 55432, Un...
# 25  [1700 American Blvd E, Bloomington, MN 55425, ...
#
#                         neighborhood                        id
# 0                                NaN  584c04838ee56059df135672
# 1                                NaN  580fa20238facc4e6ffd1569
# 2                                NaN  58517cc7739d855b44e53255
# 3                                NaN  51254ee3e4b0597635a30975
# 4                                NaN  4b5864b8f964a520c35528e3
# 5                                NaN  5beee5d5625a66002c783fba
# 6                                NaN  451f6c35f964a5209e3a1fe3
# 7                                NaN  5b142c22c58ed7002c9219a1
# 8                                NaN  5d9e2d3d3155f3000bd6a06c
# 9                                NaN  5cb20be9a35f46002557ea67
# 10                               NaN  59144c1a5d891b0a80017201
# 11                               NaN  5855d840ce593d5304f96945
# 12                   Webber - Camden  5aa4240b4a1cc021996bbdb3
# 13                               NaN  5a49d561e55d8b05322b7445
# 14                               NaN  53872b4c498e75f52c1389e9
# 15                               NaN  4c629ec6edd320a1a046ad29
# 16                               NaN  4bc4d71fabf495213ea5c593
# 17                               NaN  58bc67512bc5e25a80ce4ec8
# 18                               NaN  5cbb22a5ad910e002c3cb5cf
# 19  Robbinsdale - Crystal - New Hope  583ba09f14250b703bae9aa5
# 20                               NaN  59b7cebd6f706a0386a204e3
# 21                               NaN  5ba55c073092be002c61098e
# 22                               NaN  5c0bd903270ee7002cb99b6c
# 23                               NaN  56c88ed8498e6709eee088c6
# 24                               NaN  5c8ee7241f8ed6002cc3d397
# 25                               NaN  5a4137d1ea1e441230558076

# %%
# Here I remove a single row that was obviously mislabelled in Foursquare (Mucci's Italian Restaurant)
dataframe_filtered = dataframe_filtered.drop([22], axis=0)
dataframe_filtered.name
# Out:
# 0                           Dunkin'
# 1     Angel Food Bakery & Donut Bar
# 2                           Dunkin'
# 3                  Glam Doll Donuts
# 4                  Donut Connection
# 5                           Dunkin'
# 6                Mel-O-Glaze Bakery
# 7                           Dunkin'
# 8                           Dunkin'
# 9                           Dunkin'
# 10                  Cardigan Donuts
# 11                 Glam Doll Donuts
# 12                The Thirsty Whale
# 13                       Sleepy V's
# 14            Bogart's Doughnut Co.
# 15               Puffy Cream Donuts
# 16         YoYo Donuts & Coffee Bar
# 17                          Dunkin'
# 18                          Dunkin'
# 19                          Dunkin'
# 20                          Dunkin'
# 21             Bogart’s Doughnut Co
# 23                          Mucci's
# 24                   Dunkin' Donuts
# 25                          Dunkin'
# Name: name, dtype: object

# %%
# getting the geojson from http://opendata.minneapolismn.gov outlining all 83 neighborhoods in Minneapolis
# !wget --quiet https://opendata.arcgis.com/datasets/055ca54e5fcc47329f081c9ef51d038e_0.geojson
print('GeoJSON file downloaded!')
# Out:
# GeoJSON file downloaded!

# %%
#I create a simple dataframe so I can combine it with existing data and plot the shop location
galaxy = pd.DataFrame({
'lat':[44.912674],
'lon':[-93.328876],
'name':['Galaxy Donuts']
})
galaxy
# Out:
#          lat        lon           name
# 0  44.912674 -93.328876  Galaxy Donuts

# %%
#geojson file with mapping data for all 83 Minneapolis neighborhoods 
mpls_geo = 'https://opendata.arcgis.com/datasets/055ca54e5fcc47329f081c9ef51d038e_0.geojson'

venues_map = folium.Map(location=[latitude, longitude], zoom_start=11) # generate map centered around Minneapolis

# add the donut shops as red circle markers
for lat, lng, name in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        color='red',
        popup=name,
        fill = False,
        fill_color=None,
        fill_opacity=0.6
    ).add_to(venues_map)


# add Galaxy as a Big Blue Donut
for lat, lon, name in zip(galaxy.lat, galaxy.lon, galaxy.name):
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        color='blue',
        popup=name,
        fill = True,
        fill_color=None,
        fill_opacity=0.4
    ).add_to(venues_map)
    
# I use a choropleth style overlay to visually represent the 83 Minneapolis neighborhoods
# for the sake of seeing where the donut shops are located in comparison this will be
# important for my final analysis
venues_map.choropleth(
    geo_data=mpls_neighborhood_geo,
    data=mpls_nbrhd1,
    columns=['neighborhood','number'],
    key_on='feature.properties.BDNAME',
    threshold_scale=[0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000, 4500],
    fill_color='YlOrRd',
    fill_opacity='0.5',
    line_opacity='0.2',
    legend_name='Crime Rate in Minneapolis',
    reset=True,
)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
