# %% [markdown]
# # Business Problem and Background
#
#     I represent a national donut shop, Galaxy Donuts, and we are expanding into the state of Minnesota. Our focus is on finding locations in the city of Minneapolis that will maximize profitability for the company. The biggest problem identified by our new CEO is our donut competition has been established for some time in the Minneapolis area. However, based on our proprietary Donut Density Ratio (DDR) we know there is room for at least one location for our brand, if not more.
#
#     We will need to analyze the 83 neighborhoods of Minneapolis proper, and make the decision based on optimal distance from location of competitor donut shops in and around Minneapolis. Finally, we want to place the location of our stores in higher density areas that will ensure plenty of traffic, as well as other activities for our customers to do after they have their minds blown by our donuts.

# %% [markdown]
# # The Data
#
#     I will be using the Foursquare API to identify all donut shops in and around the city of Minneapolis. These will be indicated with red dots on the map. Next, I will determine which neighborhoods are the optimal/maximal distance from the other donut shops.
#
#     Once I have that list of neighborhoods, I will analyze those specific neighborhoods, dividing out all residential and industrial space, leaving only commercial space. If needed I will utilize city of Minneapolis open source data to help with this determination. Then I will use the Foursquare API to find businesses that might complement a donut shop (list still being determined, but will be included in the final report), and attempt to place the neighborhood in an area where the mean customer scores are highest, indicating a more satisfying experience/location.
#
#     The final work product will be a map of Minneapolis, linked to the Foursquare API denoting all competitors, and I will use all the data discussed above to place the coveted blue dot where Galaxy Donuts will open its newest location(s). All the findings will be returned in a formatted report with visuals, and I will also write the computer program used for analysis in a Jupyter Notebook and share it on my Github page with my colleagues.

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.12
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Libraries imported.

# %%
CLIENT_ID = 'G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX' # your Foursquare ID
CLIENT_SECRET = 'WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentials:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentials:
# CLIENT_ID: G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX
# CLIENT_SECRET:WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC

# %%
address = 'Minneapolis, MN'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 44.9706705 -93.268217735811

# %%
radius = 30000
print(' .... OK!')
# Out:
#  .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d148941735&intent=browse&radius=30000&client_id={}&client_secret={}&ll={},{}&v={}&query='.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?categoryId=4bf58dd8d48988d148941735&intent=browse&radius=30000&client_id=G5T2H5YFJAPACKLEQST13SJLTRRB4QMHFGJMDF0ZSRHSXPDX&client_secret=WB3CGZOIHBTSLJYERUI3VORHYWDEAF5R034JZRT3M4TVXRYC&ll=44.9706705,-93.268217735811&v=20180604&query='

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5da75998f9dbde003843ccf5'},
#  'response': {'venues': [{'id': '584c04838ee56059df135672',
#     'name': "Dunkin'",
#     'location': {'address': 'MSP Airport, Terminal 1',
#      'crossStreet': 'Main Concourse',
#      'lat': 44.88374364677225,
#      'lng': -93.21137493853037,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.88374364677225,
#        'lng': -93.21137493853037}],
#      'distance': 10663,
#      'postalCode': '55111',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['MSP Airport, Terminal 1 (Main Concourse)',
#       'Saint Paul, MN 55111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '580fa20238facc4e6ffd1569',
#     'name': 'Angel Food Bakery & Donut Bar',
#     'location': {'address': 'Concourse E',
#      'lat': 44.8850400628044,
#      'lng': -93.21256634765209,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.8850400628044,
#        'lng': -93.21256634765209}],
#      'distance': 10492,
#      'postalCode': '55111',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Concourse E',
#       'Saint Paul, MN 55111',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '4b5864b8f964a520c35528e3',
#     'name': 'Donut Connection',
#     'location': {'address': '1037 1st Ave E',
#      'lat': 44.80054540165129,
#      'lng': -93.5131151359874,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.80054540165129,
#        'lng': -93.5131151359874}],
#      'distance': 27050,
#      'postalCode': '55379',
#      'cc': 'US',
#      'city': 'Shakopee',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1037 1st Ave E',
#       'Shakopee, MN 55379',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '58517cc7739d855b44e53255',
#     'name': "Dunkin'",
#     'location': {'address': '2425 Rice St',
#      'lat': 45.01396688648932,
#      'lng': -93.1067315053491,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.01396688648932,
#        'lng': -93.1067315053491}],
#      'distance': 13595,
#      'postalCode': '55113',
#      'cc': 'US',
#      'city': 'Roseville',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2425 Rice St',
#       'Roseville, MN 55113',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '51254ee3e4b0597635a30975',
#     'name': 'Glam Doll Donuts',
#     'location': {'address': '2605 Nicollet Ave',
#      'crossStreet': 'at E 26th St.',
#      'lat': 44.955156072462565,
#      'lng': -93.27781590260867,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.955156072462565,
#        'lng': -93.27781590260867}],
#      'distance': 1885,
#      'postalCode': '55408',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['2605 Nicollet Ave (at E 26th St.)',
#       'Minneapolis, MN 55408',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '451f6c35f964a5209e3a1fe3',
#     'name': 'Mel-O-Glaze Bakery',
#     'location': {'address': '4800 28th Ave S',
#      'crossStreet': 'at E Minnehaha Pkwy',
#      'lat': 44.91586386149392,
#      'lng': -93.23230649696275,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.91586386149392,
#        'lng': -93.23230649696275}],
#      'distance': 6725,
#      'postalCode': '55417',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4800 28th Ave S (at E Minnehaha Pkwy)',
#       'Minneapolis, MN 55417',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5aa4240b4a1cc021996bbdb3',
#     'name': 'The Thirsty Whale',
#     'location': {'address': '4149 Fremont Ave N',
#      'lat': 45.03128143363127,
#      'lng': -93.29587187241299,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.03128143363127,
#        'lng': -93.29587187241299}],
#      'distance': 7089,
#      'postalCode': '55412',
#      'cc': 'US',
#      'neighborhood': 'Webber - Camden',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['4149 Fremont Ave N',
#       'Minneapolis, MN 55412',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5beee5d5625a66002c783fba',
#     'name': "Dunkin'",
#     'location': {'lat': 44.88410763898639,
#      'lng': -93.30836257250284,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.88410763898639,
#        'lng': -93.30836257250284}],
#      'distance': 10142,
#      'postalCode': '55423',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Minneapolis, MN 55423', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '59144c1a5d891b0a80017201',
#     'name': 'Cardigan Donuts',
#     'location': {'address': '40 S 7th St #207',
#      'lat': 44.97772595833002,
#      'lng': -93.27324894412774,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.97772595833002,
#        'lng': -93.27324894412774}],
#      'distance': 879,
#      'postalCode': '55454',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['40 S 7th St #207',
#       'Minneapolis, MN 55454',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'delivery': {'id': '589115',
#      'url': 'https://www.grubhub.com/restaurant/cardigan-donuts-40-s-7th-st-ste-207-minneapolis/589115?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=589115',
#      'provider': {'name': 'grubhub',
#       'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#        'sizes': [40, 50],
#        'name': '/delivery_provider_grubhub_20180129.png'}}},
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '4bc4d71fabf495213ea5c593',
#     'name': 'YoYo Donuts & Coffee Bar',
#     'location': {'address': '5757 Sanibel Dr',
#      'crossStreet': 'at Shady Oak Road',
#      'lat': 44.900312699515695,
#      'lng': -93.42233441664136,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.900312699515695,
#        'lng': -93.42233441664136}],
#      'distance': 14451,
#      'postalCode': '55343',
#      'cc': 'US',
#      'city': 'Hopkins',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['5757 Sanibel Dr (at Shady Oak Road)',
#       'Hopkins, MN 55343',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '54181465'},
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '583ba09f14250b703bae9aa5',
#     'name': "Dunkin'",
#     'location': {'address': '7820 42nd Ave N',
#      'lat': 45.03319412589679,
#      'lng': -93.37891064123318,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.03319412589679,
#        'lng': -93.37891064123318}],
#      'distance': 11151,
#      'postalCode': '55427',
#      'cc': 'US',
#      'neighborhood': 'Robbinsdale - Crystal - New Hope',
#      'city': 'New Hope',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['7820 42nd Ave N',
#       'New Hope, MN 55427',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5cb20be9a35f46002557ea67',
#     'name': "Dunkin'",
#     'location': {'address': '1420 Yankee Doodle Rd',
#      'crossStreet': 'at Pilot Knob Rd',
#      'lat': 44.8331594,
#      'lng': -93.1687155,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.8331594,
#        'lng': -93.1687155}],
#      'distance': 17201,
#      'postalCode': '55121',
#      'cc': 'US',
#      'city': 'Eagan',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1420 Yankee Doodle Rd (at Pilot Knob Rd)',
#       'Eagan, MN 55121',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '53872b4c498e75f52c1389e9',
#     'name': "Bogart's Doughnut Co.",
#     'location': {'address': '904 W 36th St',
#      'lat': 44.937735526956516,
#      'lng': -93.29105600533794,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.937735526956516,
#        'lng': -93.29105600533794}],
#      'distance': 4083,
#      'postalCode': '55408',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['904 W 36th St',
#       'Minneapolis, MN 55408',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '90123245'},
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5855d840ce593d5304f96945',
#     'name': 'Glam Doll Donuts',
#     'location': {'address': '519 Central Ave NE',
#      'lat': 44.98958329159745,
#      'lng': -93.25266389631834,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.98958329159745,
#        'lng': -93.25266389631834}],
#      'distance': 2435,
#      'postalCode': '55413',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['519 Central Ave NE',
#       'Minneapolis, MN 55413',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5a49d561e55d8b05322b7445',
#     'name': "Sleepy V's",
#     'location': {'address': '1226 2nd St NE',
#      'crossStreet': '13th',
#      'lat': 45.00075584468196,
#      'lng': -93.26630711664653,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.00075584468196,
#        'lng': -93.26630711664653}],
#      'distance': 3352,
#      'postalCode': '55413',
#      'cc': 'US',
#      'city': 'Minneapolis',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['1226 2nd St NE (13th)',
#       'Minneapolis, MN 55413',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '4c629ec6edd320a1a046ad29',
#     'name': 'Puffy Cream Donuts',
#     'location': {'address': '3390 Coachman Rd',
#      'crossStreet': 'Yankee Doodle Rd',
#      'lat': 44.83384107852124,
#      'lng': -93.17957700674667,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.83384107852124,
#        'lng': -93.17957700674667}],
#      'distance': 16758,
#      'postalCode': '55121',
#      'cc': 'US',
#      'city': 'Eagan',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['3390 Coachman Rd (Yankee Doodle Rd)',
#       'Eagan, MN 55121',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5b142c22c58ed7002c9219a1',
#     'name': "Dunkin'",
#     'location': {'address': '9595 Zachary Ln N',
#      'lat': 45.128771760267725,
#      'lng': -93.42302326667033,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.128771760267725,
#        'lng': -93.42302326667033}],
#      'distance': 21400,
#      'postalCode': '55369',
#      'cc': 'US',
#      'city': 'Maple Grove',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['9595 Zachary Ln N',
#       'Maple Grove, MN 55369',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '58bc67512bc5e25a80ce4ec8',
#     'name': "Dunkin'",
#     'location': {'address': '13650 Hanson Blvd NW Ste 114',
#      'lat': 45.218714888550714,
#      'lng': -93.30708173843391,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.218714888550714,
#        'lng': -93.30708173843391}],
#      'distance': 27780,
#      'postalCode': '55304',
#      'cc': 'US',
#      'city': 'Andover',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['13650 Hanson Blvd NW Ste 114',
#       'Andover, MN 55304',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '56c88ed8498e6709eee088c6',
#     'name': "Mucci's",
#     'location': {'address': '786 Randolph Ave',
#      'lat': 44.92677654048905,
#      'lng': -93.13330789970918,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.92677654048905,
#        'lng': -93.13330789970918}],
#      'distance': 11698,
#      'postalCode': '55102',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['786 Randolph Ave',
#       'Saint Paul, MN 55102',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '59b7cebd6f706a0386a204e3',
#     'name': "Dunkin'",
#     'location': {'lat': 44.90933094406156,
#      'lng': -93.08006309858256,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.90933094406156,
#        'lng': -93.08006309858256}],
#      'distance': 16322,
#      'postalCode': '55118',
#      'cc': 'US',
#      'city': 'Saint Paul',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['Saint Paul, MN 55118', 'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5c8ee7241f8ed6002cc3d397',
#     'name': "Dunkin' Donuts",
#     'location': {'address': '8300 University Ave NE',
#      'lat': 45.119137,
#      'lng': -93.264728,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 45.119137,
#        'lng': -93.264728}],
#      'distance': 16529,
#      'postalCode': '55432',
#      'cc': 'US',
#      'city': 'Fridley',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['8300 University Ave NE',
#       'Fridley, MN 55432',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '5bedf07e838e59002c8a20f7',
#     'name': "Dunkin'",
#     'location': {'address': '6529 Penn Ave S',
#      'lat': 44.88418995679434,
#      'lng': -93.30828960921002,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.88418995679434,
#        'lng': -93.30828960921002}],
#      'distance': 10131,
#      'postalCode': '55423',
#      'cc': 'US',
#      'city': 'Richfield',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['6529 Penn Ave S',
#       'Richfield, MN 55423',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d148941735',
#       'name': 'Donut Shop',
#       'pluralName': 'Donut Shops',
#       'shortName': 'Donuts',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/donuts_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False},
#    {'id': '4b1a7cf7f964a5200beb23e3',
#     'name': "Denny's 5th Avenue Bakery",
#     'location': {'address': '7840 5th Ave S',
#      'crossStreet': 'off American Blvd E',
#      'lat': 44.8605355,
#      'lng': -93.2700709,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 44.8605355,
#        'lng': -93.2700709}],
#      'distance': 12260,
#      'postalCode': '55420',
#      'cc': 'US',
#      'city': 'Bloomington',
#      'state': 'MN',
#      'country': 'United States',
#      'formattedAddress': ['7840 5th Ave S (off American Blvd E)',
#       'Bloomington, MN 55420',
#       'United States']},
#     'categories': [{'id': '4bf58dd8d48988d16a941735',
#       'name': 'Bakery',
#       'pluralName': 'Bakeries',
#       'shortName': 'Bakery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1571248536',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id                           name  \
# 0  584c04838ee56059df135672                        Dunkin'
# 1  580fa20238facc4e6ffd1569  Angel Food Bakery & Donut Bar
# 2  4b5864b8f964a520c35528e3               Donut Connection
# 3  58517cc7739d855b44e53255                        Dunkin'
# 4  51254ee3e4b0597635a30975               Glam Doll Donuts
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1571248536    False
# 1  [{'id': '4bf58dd8d48988d16a941735', 'name': 'B...  v-1571248536    False
# 2  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1571248536    False
# 3  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1571248536    False
# 4  [{'id': '4bf58dd8d48988d148941735', 'name': 'D...  v-1571248536    False
#
#           location.address location.crossStreet  location.lat  location.lng  \
# 0  MSP Airport, Terminal 1       Main Concourse     44.883744    -93.211375
# 1              Concourse E                  NaN     44.885040    -93.212566
# 2           1037 1st Ave E                  NaN     44.800545    -93.513115
# 3             2425 Rice St                  NaN     45.013967    -93.106732
# 4        2605 Nicollet Ave        at E 26th St.     44.955156    -93.277816
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 44.88374364677225...              10663
# 1  [{'label': 'display', 'lat': 44.8850400628044,...              10492
# 2  [{'label': 'display', 'lat': 44.80054540165129...              27050
# 3  [{'label': 'display', 'lat': 45.01396688648932...              13595
# 4  [{'label': 'display', 'lat': 44.95515607246256...               1885
#
#   location.postalCode location.cc location.city location.state  \
# 0               55111          US    Saint Paul             MN
# 1               55111          US    Saint Paul             MN
# 2               55379          US      Shakopee             MN
# 3               55113          US     Roseville             MN
# 4               55408          US   Minneapolis             MN
#
#   location.country                          location.formattedAddress  \
# 0    United States  [MSP Airport, Terminal 1 (Main Concourse), Sai...
# 1    United States  [Concourse E, Saint Paul, MN 55111, United Sta...
# 2    United States  [1037 1st Ave E, Shakopee, MN 55379, United St...
# 3    United States  [2425 Rice St, Roseville, MN 55113, United Sta...
# 4    United States  [2605 Nicollet Ave (at E 26th St.), Minneapoli...
#
#   location.neighborhood delivery.id delivery.url delivery.provider.name  \
# 0                   NaN         NaN          NaN                    NaN
# 1                   NaN         NaN          NaN                    NaN
# 2                   NaN         NaN          NaN                    NaN
# 3                   NaN         NaN          NaN                    NaN
# 4                   NaN         NaN          NaN                    NaN
#
#   delivery.provider.icon.prefix delivery.provider.icon.sizes  \
# 0                           NaN                          NaN
# 1                           NaN                          NaN
# 2                           NaN                          NaN
# 3                           NaN                          NaN
# 4                           NaN                          NaN
#
#   delivery.provider.icon.name venuePage.id
# 0                         NaN          NaN
# 1                         NaN          NaN
# 2                         NaN          NaN
# 3                         NaN          NaN
# 4                         NaN          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                              name          categories  \
# 0                         Dunkin'          Donut Shop
# 1   Angel Food Bakery & Donut Bar              Bakery
# 2                Donut Connection          Donut Shop
# 3                         Dunkin'          Donut Shop
# 4                Glam Doll Donuts          Donut Shop
# 5              Mel-O-Glaze Bakery              Bakery
# 6               The Thirsty Whale              Bakery
# 7                         Dunkin'          Donut Shop
# 8                 Cardigan Donuts          Donut Shop
# 9        YoYo Donuts & Coffee Bar          Donut Shop
# 10                        Dunkin'          Donut Shop
# 11                        Dunkin'          Donut Shop
# 12          Bogart's Doughnut Co.          Donut Shop
# 13               Glam Doll Donuts          Donut Shop
# 14                     Sleepy V's          Donut Shop
# 15             Puffy Cream Donuts          Donut Shop
# 16                        Dunkin'          Donut Shop
# 17                        Dunkin'          Donut Shop
# 18                        Mucci's  Italian Restaurant
# 19                        Dunkin'          Donut Shop
# 20                 Dunkin' Donuts          Donut Shop
# 21                        Dunkin'          Donut Shop
# 22      Denny's 5th Avenue Bakery              Bakery
#
#                          address          crossStreet        lat        lng  \
# 0        MSP Airport, Terminal 1       Main Concourse  44.883744 -93.211375
# 1                    Concourse E                  NaN  44.885040 -93.212566
# 2                 1037 1st Ave E                  NaN  44.800545 -93.513115
# 3                   2425 Rice St                  NaN  45.013967 -93.106732
# 4              2605 Nicollet Ave        at E 26th St.  44.955156 -93.277816
# 5                4800 28th Ave S  at E Minnehaha Pkwy  44.915864 -93.232306
# 6             4149 Fremont Ave N                  NaN  45.031281 -93.295872
# 7                            NaN                  NaN  44.884108 -93.308363
# 8               40 S 7th St #207                  NaN  44.977726 -93.273249
# 9                5757 Sanibel Dr    at Shady Oak Road  44.900313 -93.422334
# 10               7820 42nd Ave N                  NaN  45.033194 -93.378911
# 11         1420 Yankee Doodle Rd     at Pilot Knob Rd  44.833159 -93.168716
# 12                 904 W 36th St                  NaN  44.937736 -93.291056
# 13            519 Central Ave NE                  NaN  44.989583 -93.252664
# 14                1226 2nd St NE                 13th  45.000756 -93.266307
# 15              3390 Coachman Rd     Yankee Doodle Rd  44.833841 -93.179577
# 16             9595 Zachary Ln N                  NaN  45.128772 -93.423023
# 17  13650 Hanson Blvd NW Ste 114                  NaN  45.218715 -93.307082
# 18              786 Randolph Ave                  NaN  44.926777 -93.133308
# 19                           NaN                  NaN  44.909331 -93.080063
# 20        8300 University Ave NE                  NaN  45.119137 -93.264728
# 21               6529 Penn Ave S                  NaN  44.884190 -93.308290
# 22                7840 5th Ave S  off American Blvd E  44.860535 -93.270071
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 44.88374364677225...     10663      55111
# 1   [{'label': 'display', 'lat': 44.8850400628044,...     10492      55111
# 2   [{'label': 'display', 'lat': 44.80054540165129...     27050      55379
# 3   [{'label': 'display', 'lat': 45.01396688648932...     13595      55113
# 4   [{'label': 'display', 'lat': 44.95515607246256...      1885      55408
# 5   [{'label': 'display', 'lat': 44.91586386149392...      6725      55417
# 6   [{'label': 'display', 'lat': 45.03128143363127...      7089      55412
# 7   [{'label': 'display', 'lat': 44.88410763898639...     10142      55423
# 8   [{'label': 'display', 'lat': 44.97772595833002...       879      55454
# 9   [{'label': 'display', 'lat': 44.90031269951569...     14451      55343
# 10  [{'label': 'display', 'lat': 45.03319412589679...     11151      55427
# 11  [{'label': 'display', 'lat': 44.8331594, 'lng'...     17201      55121
# 12  [{'label': 'display', 'lat': 44.93773552695651...      4083      55408
# 13  [{'label': 'display', 'lat': 44.98958329159745...      2435      55413
# 14  [{'label': 'display', 'lat': 45.00075584468196...      3352      55413
# 15  [{'label': 'display', 'lat': 44.83384107852124...     16758      55121
# 16  [{'label': 'display', 'lat': 45.12877176026772...     21400      55369
# 17  [{'label': 'display', 'lat': 45.21871488855071...     27780      55304
# 18  [{'label': 'display', 'lat': 44.92677654048905...     11698      55102
# 19  [{'label': 'display', 'lat': 44.90933094406156...     16322      55118
# 20  [{'label': 'display', 'lat': 45.119137, 'lng':...     16529      55432
# 21  [{'label': 'display', 'lat': 44.88418995679434...     10131      55423
# 22  [{'label': 'display', 'lat': 44.8605355, 'lng'...     12260      55420
#
#     cc         city state        country  \
# 0   US   Saint Paul    MN  United States
# 1   US   Saint Paul    MN  United States
# 2   US     Shakopee    MN  United States
# 3   US    Roseville    MN  United States
# 4   US  Minneapolis    MN  United States
# 5   US  Minneapolis    MN  United States
# 6   US  Minneapolis    MN  United States
# 7   US  Minneapolis    MN  United States
# 8   US  Minneapolis    MN  United States
# 9   US      Hopkins    MN  United States
# 10  US     New Hope    MN  United States
# 11  US        Eagan    MN  United States
# 12  US  Minneapolis    MN  United States
# 13  US  Minneapolis    MN  United States
# 14  US  Minneapolis    MN  United States
# 15  US        Eagan    MN  United States
# 16  US  Maple Grove    MN  United States
# 17  US      Andover    MN  United States
# 18  US   Saint Paul    MN  United States
# 19  US   Saint Paul    MN  United States
# 20  US      Fridley    MN  United States
# 21  US    Richfield    MN  United States
# 22  US  Bloomington    MN  United States
#
#                                      formattedAddress  \
# 0   [MSP Airport, Terminal 1 (Main Concourse), Sai...
# 1   [Concourse E, Saint Paul, MN 55111, United Sta...
# 2   [1037 1st Ave E, Shakopee, MN 55379, United St...
# 3   [2425 Rice St, Roseville, MN 55113, United Sta...
# 4   [2605 Nicollet Ave (at E 26th St.), Minneapoli...
# 5   [4800 28th Ave S (at E Minnehaha Pkwy), Minnea...
# 6   [4149 Fremont Ave N, Minneapolis, MN 55412, Un...
# 7              [Minneapolis, MN 55423, United States]
# 8   [40 S 7th St #207, Minneapolis, MN 55454, Unit...
# 9   [5757 Sanibel Dr (at Shady Oak Road), Hopkins,...
# 10  [7820 42nd Ave N, New Hope, MN 55427, United S...
# 11  [1420 Yankee Doodle Rd (at Pilot Knob Rd), Eag...
# 12  [904 W 36th St, Minneapolis, MN 55408, United ...
# 13  [519 Central Ave NE, Minneapolis, MN 55413, Un...
# 14  [1226 2nd St NE (13th), Minneapolis, MN 55413,...
# 15  [3390 Coachman Rd (Yankee Doodle Rd), Eagan, M...
# 16  [9595 Zachary Ln N, Maple Grove, MN 55369, Uni...
# 17  [13650 Hanson Blvd NW Ste 114, Andover, MN 553...
# 18  [786 Randolph Ave, Saint Paul, MN 55102, Unite...
# 19              [Saint Paul, MN 55118, United States]
# 20  [8300 University Ave NE, Fridley, MN 55432, Un...
# 21  [6529 Penn Ave S, Richfield, MN 55423, United ...
# 22  [7840 5th Ave S (off American Blvd E), Bloomin...
#
#                         neighborhood                        id
# 0                                NaN  584c04838ee56059df135672
# 1                                NaN  580fa20238facc4e6ffd1569
# 2                                NaN  4b5864b8f964a520c35528e3
# 3                                NaN  58517cc7739d855b44e53255
# 4                                NaN  51254ee3e4b0597635a30975
# 5                                NaN  451f6c35f964a5209e3a1fe3
# 6                    Webber - Camden  5aa4240b4a1cc021996bbdb3
# 7                                NaN  5beee5d5625a66002c783fba
# 8                                NaN  59144c1a5d891b0a80017201
# 9                                NaN  4bc4d71fabf495213ea5c593
# 10  Robbinsdale - Crystal - New Hope  583ba09f14250b703bae9aa5
# 11                               NaN  5cb20be9a35f46002557ea67
# 12                               NaN  53872b4c498e75f52c1389e9
# 13                               NaN  5855d840ce593d5304f96945
# 14                               NaN  5a49d561e55d8b05322b7445
# 15                               NaN  4c629ec6edd320a1a046ad29
# 16                               NaN  5b142c22c58ed7002c9219a1
# 17                               NaN  58bc67512bc5e25a80ce4ec8
# 18                               NaN  56c88ed8498e6709eee088c6
# 19                               NaN  59b7cebd6f706a0386a204e3
# 20                               NaN  5c8ee7241f8ed6002cc3d397
# 21                               NaN  5bedf07e838e59002c8a20f7
# 22                               NaN  4b1a7cf7f964a5200beb23e3

# %%
dataframe_filtered.name
# Out:
# 0                           Dunkin'
# 1     Angel Food Bakery & Donut Bar
# 2                  Donut Connection
# 3                           Dunkin'
# 4                  Glam Doll Donuts
# 5                Mel-O-Glaze Bakery
# 6                 The Thirsty Whale
# 7                           Dunkin'
# 8                   Cardigan Donuts
# 9          YoYo Donuts & Coffee Bar
# 10                          Dunkin'
# 11                          Dunkin'
# 12            Bogart's Doughnut Co.
# 13                 Glam Doll Donuts
# 14                       Sleepy V's
# 15               Puffy Cream Donuts
# 16                          Dunkin'
# 17                          Dunkin'
# 18                          Mucci's
# 19                          Dunkin'
# 20                   Dunkin' Donuts
# 21                          Dunkin'
# 22        Denny's 5th Avenue Bakery
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around Minneapolis

# add the donut shops as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='red',
        popup=label,
        fill = True,
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
